# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install xlrd
# Out:
# ...
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    -------- ------------------------------- 20.5/96.5 kB 27.3 kB/s eta 0:00:03
#    -------- ------------------------------- 20.5/96.5 kB 27.3 kB/s eta 0:00:03
#    -------- ------------------------------- 20.5/96.5 kB 27.3 kB/s eta 0:00:03
#    ------------ --------------------------- 30.7/96.5 kB 39.8 kB/s eta 0:00:02
#    ---------------- ----------------------- 41.0/96.5 kB 56.2 kB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('tested.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
import matplotlib.pyplot as plt

# %%
x = df['Age']
y = df['Fare']


colors = ['red' if age < 5 else 
          'blue' if age < 10 else 
          'black' if age < 20 else
          'brown' if age < 30 else  
          'pink' if age < 40 else 
          'yellow' if age < 50 else 
          'white' for age in x]


plt.scatter(x, y, c=colors)
plt.xlabel('Age (red if > 30)')
plt.ylabel('Fare (green if <= 30)')
plt.title('Scatter Plot of Age vs Fare')
plt.show()
