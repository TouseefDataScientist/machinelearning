# %%
# %pip install xlrd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/96.5 kB 163.8 kB/s eta 0:00:01
#    ---------------- ----------------------- 41.0/96.5 kB 178.6 kB/s eta 0:00:01
#    ------------------------- -------------- 61.4/96.5 kB 217.9 kB/s eta 0:00:01
#    --------------------------------- ------ 81.9/96.5 kB 254.2 kB/s eta 0:00:01
#    ---------------------------------------- 96.5/96.5 kB 250.8 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
df=pd.read_csv('titanic dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
y=df['Fare']
x=df['Age']
colors = ['red' if 0<=age <= 5 else
    'yellow' if 6 <= age <= 12 else
    'blue' if 13 <= age <= 19 else
    'green' if 20 <= age <= 30 else
    'brown' if 31 <= age <= 40 else
    'purple' for age in x]
plt.scatter(x, y, c=colors)

age_labels = ['red for toddlers', 'yellow for kids', 'blue for teenagers',
             'green for youngers', 'brown for adults', 'purple for elders']

plt.legend(age_labels, title="Age Groups")  

plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Fare vs. Age ')

plt.show()
