# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/96.5 kB ? eta -:--:--
#    ---------------- ----------------------- 41.0/96.5 kB 393.8 kB/s eta 0:00:01
#    ---------------------------------------- 96.5/96.5 kB 501.7 kB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: C:\Users\PMYLS\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
df=pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x=df['Age']
y=df['Fare']
plt.scatter(x,y)
plt.show()

# %%
x=df['Age']
y=df['Fare']

colors =[
    'red' if age>=1 and age<=4 else
    'blue' if age>=5 and age<=12 else
    'green' if age>=13 and age<=19 else
    'yellow' if age>=20 and age<=39 else
    'purple' if age>=40 and age<=59 else
    'orange' 
    for age in x 
]


plt.title('Scatter plot representing different categories of Ages')
plt.xlabel('Age(Coloured according to different categories)')
plt.ylabel('Fare')

plt.scatter(x,y,c=colors)

plt.legend(['Baby 1-4(red)','Child 5-12(blue)','Teen 13-19(green)','Adult 20-39(yellow)',
            'Middle Age Adult 40-59(purple)','Old--Above 60(orange)'])



plt.show()
