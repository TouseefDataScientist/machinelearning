# %%
# !pip install pandas
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize= (30,10))
x = np.array([1,2,3,4,5])
y = np.array([4,6,9,11,15])
plt.xlabel('ai')
plt.ylabel('sales')
plt.title ('graph 1')
plt.grid()
plt.subplot(2,5,1)
plt.scatter(x,y)


x= np.array([7,9,10,11,15])
y = np.array([4,6,7,18,10])
plt.xlabel('ai')
plt.ylabel('sales')
plt.title ('graph 1')
plt.plot(x,y)


plt.grid()
plt.subplot(2,5,2)

x= np.array([7,11,15,16,19])
y = np.array([4,7,9,15,25])
plt.xlabel('ai')
plt.ylabel('sales')
plt.title ('graph 1')

plt.grid()
plt.subplot(2,5,3)
plt.plot(x,y)

x= np.array([7,9,11,12,15])
y = np.array([4,6,9,11,15])
plt.xlabel('ai')
plt.ylabel('sales')
plt.title ('graph 1')

plt.grid()
plt.subplot(2,5,4)
plt.plot(x,y)

x= np.array([7,9,10,16,18])
y= np.array([4,6,9,11,15])
plt.xlabel('ai')
plt.ylabel('sales')
plt.title ('graph 1')

plt.grid()
plt.subplot(2,5,5)
plt.plot(x,y)



x = np.array([1,2,3,4,5])
y = np.array([4,6,9,11,15])
plt.xlabel('ai')
plt.ylabel('sales')
plt.title ('graph 1')

plt.grid()
plt.subplot(2,5,6)
plt.plot(x,y)

x= np.array([7,9,10,11,15])
y= np.array([4,6,7,18,10])
plt.xlabel('ai')
plt.ylabel('sales')
plt.title ('graph 1')

plt.grid()
plt.subplot(2,5,7)
plt.plot(x,y)

x= np.array([7,11,15,16,19])
y = np.array([4,7,9,15,25])
plt.xlabel('ai')
plt.ylabel('sales')
plt.title ('graph 1')

plt.grid()
plt.subplot(2,5,8)
plt.plot(x,y)

x= np.array([7,9,11,12,15])
y= np.array([4,6,9,11,15])
plt.xlabel('ai')
plt.ylabel('sales')
plt.title ('graph 1')
plt.grid()
plt.subplot(2,5,9)
plt.plot(x,y)

x= np.array([7,9,10,16,18])
y = np.array([4,6,9,11,15])
plt.xlabel('ai')
plt.ylabel('sales')
plt.title ('graph 1')
plt.grid()
plt.subplot(2,5,10)
plt.plot(x,y)

# %%
df = pd.read_csv('excel.csv')
df
# Out:
#    product  price
# 0        1     11
# 1        2     12
# 2        3     13
# 3        4     14
# 4        5     15
# 5        6     16
# 6        7     17
# 7        8     18
# 8        9     19

# %%
df = pd .read_excel('excel.xlsx')
df
# Out:
#    product  price
# 0        1     11
# 1        2     12
# 2        3     13
# 3        4     14
# 4        5     15
# 5        6     16
# 6        7     17
# 7        8     18
# 8        9     19

# %%
x = df['price']
y =df['product']
plt.scatter(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %%
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x19f0225bfb0>,
# ...
#  [Text(1.0641567434856065, 0.2785146769814997, ''),
#   Text(0.7732791695434269, 0.7823294229097024, ''),
#   Text(0.21616827460016166, 1.07855054450702, ''),
#   Text(-0.45907228207823736, 0.9996262500692343, ''),
#   Text(-0.9829958910884498, 0.4936791246378812, ''),
#   Text(-1.0641567500047129, -0.27851465207311343, ''),
#   Text(-0.5720177687419206, -0.9395720686799469, ''),
#   Text(0.29087757787305796, -1.0608441142272993, ''),
#   Text(0.9942171520029749, -0.47067213074824554, '')])

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x19f02355ca0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x19f023561e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x19f01fd3320>],
#  'medians': [<matplotlib.lines.Line2D at 0x19f02356780>],
#  'fliers': [<matplotlib.lines.Line2D at 0x19f023569f0>],
#  'means': []}

# %%
colors =np.array([0,10,20,30,40,50,60,70,80])
plt.scatter(x,y, c= colors, cmap = 'viridis')

plt.colorbar()

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
x = df['Age']
y =df['Fare']
plt.scatter(x,y, color = 'red')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x = df['Age']
y =df['Fare']
plt.scatter(x,y, color = 'red')

# %%
plt.scatter(x, y, c='red', label='Age')  # Plot Age in red
plt.scatter(x, y, c='green', label='Fare', alpha=0.5)  # Plot Fare in green with some transparency

plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot of Age vs Fare')

# Add legend to explain the colors
plt.legend(['Age (red)', 'Fare (green)'])

plt.show()

# %%
#different colors for different age groups

def get_color(age):
    if age <= 15:
        return 'blue'
    elif age <= 25:
        return 'green'
    elif age <= 35:
        return 'red'
    elif age <= 45:
        return 'purple'
    else:
        return 'orange'


df['Color'] = df['Age'].apply(get_color)


plt.figure(figsize=(10, 5))
S
for color, group in df.groupby('Color'):
    plt.scatter(group['Age'], group['Fare'], color=color, label=color, edgecolors='black')
    
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot: different colors for different age groups')
plt.show()
