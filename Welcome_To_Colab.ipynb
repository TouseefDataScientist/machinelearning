# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('titanic dataset.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Sample data
x = data['Age']
y = data['Fare']

# Assign colors based on conditions
# Create a scatter plot with specified colors
#colors = ['red' if age > 30 else 'blue' for age in x]
colors = [
    'red' if 0<=age <= 5 else
    'pink' if 6 <= age <= 10 else
    'orange' if 11 <= age <= 20 else
    'yellow' if 21 <= age <= 30 else
    'brown' if 31 <= age <= 40 else
    'blue' if 41 <= age <= 50 else
    'hotpink' for age in x]
plt.scatter(x, y, c=colors)
#plt.xlabel(
    #'Age (red if he is toddler,pink if he is kid , orange if teenager , yellow if he is young , brown if adults , blue if mature hotpink if he is retired')
plt.xlabel('Age(red if<=30)')
plt.ylabel('Fare (green if <= 30)')
plt.title('Scatter Plot of Age vs Fare')
#plt.legend(['Age 0-5 (red)'])
#plt.legend(['Age 0-5','Age 6-10','Age 11-20','Age 21-30','Age 31-40','Age 41-50','Age 51-60'])
plt.legend(title="colors:red for toddlers , pink for kids,orange for teenage,yellow for adults")
plt.show()
#plt.xlabel("Fare", color='Green', fontsize=10)
#plt.ylabel("Age", color='red', fontsize=10)
#plt.title("Scatter plot", color='Blue', fontsize=15)

# Scatter plot with 'Fare' as x-axis and 'Age' as y-axis, using the created color list
#plt.scatter(x, y, color=colors)

#plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
