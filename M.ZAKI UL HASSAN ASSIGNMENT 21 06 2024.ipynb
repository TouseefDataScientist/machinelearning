# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# NOW I WILL ASSIGN X TO AGE OF TITANIC DATASET AND Y TO FARE OF TITANIC DATASET
x = df["Age"]
y = df['Fare']

# %%
# NOW I HAVE CREATED SCATTER PLOT BETWEEN AGE AND FARE
plt.scatter(x,y)
plt.show() #SHOW() IS USED FOR SHOWING DESIRED PLOT

# %%
# NOW I WILL DIFFERENTIATE THEM WITH COLOR AGE WITH RED AND FARE WITH BROWN
plt.scatter(x, y, c='yellow', label='Age')
plt.scatter(x, y, c='brown', label='Fare')

# %%
# NOW I WILL DIFFERENTIATE THEM WITH COLOR AGE WITH RED AND FARE WITH BROWN
plt.scatter(x, y, c='red', label='Age')
plt.scatter(x, y, c='green', label='Fare')

# NOW I WILL CREATE LABLES OF AGE AND FARE 
plt.xlabel('Age')
plt.ylabel('Fare')
# Out:
# Text(0, 0.5, 'Fare')

# %%
# NOW I WILL DIFFERENTIATE THEM WITH COLOR AGE WITH RED AND FARE WITH BROWN
plt.scatter(x, y, c='red', label='Age')
plt.scatter(x, y, c='green', label='Fare')

# NOW I WILL CREATE LABLES OF AGE AND FARE 
plt.xlabel('Age')
plt.ylabel('Fare')

# NOW I WLL GIVE TITLE OF SCATTER
plt.title('Scatter Plot of Age vs Fare')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Age vs Fare')

# %%
# NOW I WILL DIFFERENTIATE THEM WITH COLOR AGE WITH RED AND FARE WITH BROWN
plt.scatter(x, y, c='blue', label='Age')
plt.scatter(x, y, c='red', label='Fare')

# NOW I WILL CREATE LABLES OF AGE AND FARE 
plt.xlabel('Age')
plt.ylabel('Fare')

# NOW I WLL GIVE TITLE OF SCATTER
plt.title('Scatter Plot of Age vs Fare')

# NOW I WILL MAKE SURE OF COLORS OF DIFFERENT FEATURES IN PLOT
plt.legend(['Age (blue)', 'Fare (red)'])

# %%
# NOW I WILL DIFFERENTIATE THEM WITH COLOR AGE WITH RED AND FARE WITH BROWN
plt.scatter(x, y, c='blue', label='Age')
plt.scatter(x, y, c='red', label='Fare')

# NOW I WILL CREATE LABLES OF AGE AND FARE 
plt.xlabel('Age')
plt.ylabel('Fare')

# NOW I WLL GIVE TITLE OF SCATTER
plt.title('Scatter Plot of Age vs Fare')

# NOW I WILL MAKE SURE OF COLORS OF DIFFERENT FEATURES IN PLOT
plt.legend(['Age (blue)', 'Fare (red)'])

# NOW I WILL GIVE THEM EDGE COLORS(MEANS OUTSIDE OR BOUNDRY COLOR) AND FACE COLOR(MEANS ACTUAL COLOR)
plt.scatter(x, y, edgecolor='blue', facecolor='red')

# %%
# NOW I WILL DIFFERENTIATE THEM WITH COLOR AGE WITH RED AND FARE WITH BROWN
plt.scatter(x, y, c='blue', label='Age')
plt.scatter(x, y, c='red', label='Fare')

# NOW I WILL CREATE LABLES OF AGE AND FARE 
plt.xlabel('Age')
plt.ylabel('Fare')

# NOW I WLL GIVE TITLE OF SCATTER
plt.title('Scatter Plot of Age vs Fare')

# NOW I WILL MAKE SURE OF COLORS OF DIFFERENT FEATURES IN PLOT
plt.legend(['Age (blue)', 'Fare (red)'])

# NOW I WILL GIVE THEM EDGE COLORS(MEANS OUTSIDE OR BOUNDRY COLOR) AND FACE COLOR(MEANS ACTUAL COLOR)
plt.scatter(x, y, edgecolor='blue', facecolor='red')

# NOW I WILL PUT THEM IN CATEGORIES WITH DIFFERENT COLORS 1-12 child
# 13-19 teen
# 20-30 adult
# 30-40 old

# # colors = ['red' if (age >= 13 & age  <=19) elif 'blue' (age >= 20 & age  <=30) elif 'green' (age >= 30 & age  <=40) else 'black' for age in x]
# for age in x:
#     if ((age >=13) & (age  <=19)):
#         colors = ['red']
#     elif ((age >= 20) & (age  <=30)):
#         colors = ['blue']
#     elif ((age >= 30) & (age  <=40)):
#         colors = ['green']
#     else:
#         colors = ['black']

# %%
# NOW I WILL DIFFERENTIATE THEM WITH COLOR AGE WITH RED AND FARE WITH BROWN
plt.scatter(x, y, c='blue', label='Age')
plt.scatter(x, y, c='red', label='Fare')

# NOW I WILL CREATE LABLES OF AGE AND FARE 
plt.xlabel('Age')
plt.ylabel('Fare')

# NOW I WLL GIVE TITLE OF SCATTER
plt.title('Scatter Plot of Age vs Fare')

# NOW I WILL MAKE SURE OF COLORS OF DIFFERENT FEATURES IN PLOT
plt.legend(['Age (blue)', 'Fare (red)'])

# NOW I WILL GIVE THEM EDGE COLORS(MEANS OUTSIDE OR BOUNDRY COLOR) AND FACE COLOR(MEANS ACTUAL COLOR)
plt.scatter(x, y, edgecolor='blue', facecolor='red')

# NOW I WILL PUT THEM IN CATEGORIES WITH DIFFERENT COLORS 1-12 child
# 13-19 teen
# 20-30 adult
# 30-40 old
colors = ['red' if age <= 12 else 'blue' if age <= 19 else 'green' if age <= 30 else 'yellow' for age in x]
plt.scatter(x, y, c=colors)
